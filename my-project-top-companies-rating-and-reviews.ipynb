# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-companies-rating-and-reviews/1000 companies list and rating.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/top-companies-rating-and-reviews/1000 companies list and rating.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0        company                       type  rating  \
# 0           0            TCS  IT Services & Consulting      3.8
# 1           1      Accenture  IT Services & Consulting      4.0
# 2           2      Cognizant  IT Services & Consulting      3.9
# 3           3          Wipro  IT Services & Consulting      3.8
# 4           4      Capgemini  IT Services & Consulting      3.9
# 5           5      HDFC Bank                   Banking      4.0
# 6           6     ICICI Bank                   Banking      4.0
# 7           7        Infosys  IT Services & Consulting      3.8
# 8           8        HCLTech  IT Services & Consulting      3.7
# 9           9  Tech Mahindra  IT Services & Consulting      3.7
#
#        reviewers           age  \
# 0  73.8k Reviews  56 years old
# 1  46.8k Reviews  35 years old
# 2  42.2k Reviews  30 years old
# 3  39.6k Reviews  79 years old
# 4  34.3k Reviews  57 years old
# 5  34.3k Reviews  30 years old
# 6  33.8k Reviews  30 years old
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0                              company  \
# 9990        9990                     H'Reck Engineers
# 9991        9991                              Hirotec
# 9992        9992                     Alteus Biogenics
# 9993        9993       Corrival Corporate Consultants
# 9994        9994                              Tenpath
# 9995        9995                      Tag Corporation
# 9996        9996  vista Processed foods (A OSI GROUP)
# 9997        9997                  Systematix Infotech
# 9998        9998                                 GUVI
# 9999        9999                  RxLogix Corporation
#
#                              type  rating   reviewers           age  \
# 9990  Engineering & Construction      4.1  73 Reviews  45 years old
# 9991             Auto Components      3.7  73 Reviews  19 years old
# 9992                      Pharma      3.4  73 Reviews  16 years old
# 9993                 Recruitment      4.2  73 Reviews  18 years old
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           10000 non-null  int64
#  1   company              10000 non-null  object
#  2   type                 9591 non-null   object
#  3   rating               10000 non-null  float64
#  4   reviewers            10000 non-null  object
#  5   age                  9211 non-null   object
#  6   highly_ratedFOR      9916 non-null   object
#  7   critically_ratedFOR  2824 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.1+ KB

# %%
# Remove rows with any NaN values
df_clean = df.dropna()

# %%
df_clean
# Out:
#       Unnamed: 0                              company  \
# 0              0                                  TCS
# 2              2                            Cognizant
# 3              3                                Wipro
# 4              4                            Capgemini
# 5              5                            HDFC Bank
# ...          ...                                  ...
# 9987        9987                  Srikalahasthi Pipes
# 9991        9991                              Hirotec
# 9993        9993       Corrival Corporate Consultants
# 9996        9996  vista Processed foods (A OSI GROUP)
# 9997        9997                  Systematix Infotech
#
#                            type  rating      reviewers           age  \
# 0     IT Services & Consulting      3.8  73.8k Reviews  56 years old
# 2     IT Services & Consulting      3.9  42.2k Reviews  30 years old
# 3     IT Services & Consulting      3.8  39.6k Reviews  79 years old
# ...

# %%
df_clean.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_33/2874819666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_clean
# Out:
#                                   company                       type  rating  \
# 0                                     TCS  IT Services & Consulting      3.8
# 2                               Cognizant  IT Services & Consulting      3.9
# 3                                   Wipro  IT Services & Consulting      3.8
# 4                               Capgemini  IT Services & Consulting      3.9
# 5                               HDFC Bank                   Banking      4.0
# ...                                   ...                        ...     ...
# 9987                  Srikalahasthi Pipes           Metals & Mining      4.0
# 9991                              Hirotec           Auto Components      3.7
# 9993       Corrival Corporate Consultants               Recruitment      4.2
# 9996  vista Processed foods (A OSI GROUP)           Analytics & KPO      4.0
# 9997                  Systematix Infotech  IT Services & Consulting      3.7
#
#           reviewers           age  \
# ...

# %%
df_clean.describe()
# Out:
#             rating
# count  2572.000000
# mean      3.934020
# std       0.204684
# min       2.700000
# 25%       3.800000
# 50%       3.900000
# 75%       4.100000
# max       4.700000

# %%
df.columns
# Out:
# Index(['company', 'type', 'rating', 'reviewers', 'age', 'highly_ratedFOR',
#        'critically_ratedFOR'],
#       dtype='object')

# %%
df['company'].value_counts()
# Out:
# company
# WPIL                                       2
# MSPL                                       2
# IndiaNIC Infotech                          2
# OASYS Tech Solutions                       2
# Institute of Advance Network Technology    2
#                                           ..
# ScoreMe Solutions                          1
# Hollister Medical                          1
# ZF India Technology Center                 1
# Associated Road Carriers                   1
# vista Processed foods (A OSI GROUP)        1
# Name: count, Length: 9112, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# IT Services & Consulting       1279
# Engineering & Construction      506
# Auto Components                 444
# Industrial Machinery            400
# Pharma                          379
#                                ...
# Leather                           5
# Startup                           2
# Conglomerate                      1
# Computer Software                 1
# Events                            1
# Name: count, Length: 86, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    1195
# 4.0    1179
# 3.9    1130
# 4.2     928
# 3.8     921
# 3.7     788
# 4.3     657
# 3.6     624
# 3.5     481
# 4.4     381
# 3.4     366
# 3.3     242
# 4.5     241
# 3.2     211
# 4.6     139
# 3.1     123
# 3.0      69
# 4.7      65
# 2.9      60
# 4.8      50
# 2.8      30
# 4.9      28
# 2.6      25
# 5.0      13
# 2.7      13
# 2.4      11
# 2.5      10
# 2.2       7
# 2.3       6
# 2.1       5
# 1.3       1
# 1.9       1
# Name: count, dtype: int64

# %%
df['company'].value_counts()
# Out:
# company
# WPIL                                       2
# MSPL                                       2
# IndiaNIC Infotech                          2
# OASYS Tech Solutions                       2
# Institute of Advance Network Technology    2
#                                           ..
# ScoreMe Solutions                          1
# Hollister Medical                          1
# ZF India Technology Center                 1
# Associated Road Carriers                   1
# vista Processed foods (A OSI GROUP)        1
# Name: count, Length: 9112, dtype: int64

# %%
df['reviewers'].value_counts()
# Out:
# reviewers
# 76 Reviews       138
# 78 Reviews       136
# 77 Reviews       128
# 75 Reviews       122
# 74 Reviews       113
#                 ...
# 768 Reviews        1
# 769 Reviews        1
# 776 Reviews        1
# 781 Reviews        1
# 73.8k Reviews      1
# Name: count, Length: 886, dtype: int64

# %%
df['highly_ratedFOR'].value_counts()
# Out:
# highly_ratedFOR
# Job Security                                                          475
# Skill Development / Learning                                          301
# Work Life Balance                                                     274
# Job Security, Work Life Balance, Company Culture                      272
# Promotions / Appraisal                                                229
#                                                                      ...
# Work Satisfaction, Company Culture, Promotions / Appraisal              1
# Work Satisfaction, Salary & Benefits                                    1
# Work Satisfaction, Company Culture, Job Security                        1
# Work Satisfaction, Salary & Benefits, Job Security                      1
# Work Satisfaction, Salary & Benefits, Skill Development / Learning      1
# Name: count, Length: 254, dtype: int64

# %%
df['critically_ratedFOR'].value_counts()
# Out:
# critically_ratedFOR
# Promotions / Appraisal                                                     1332
# Promotions / Appraisal, Salary & Benefits                                   412
# Salary & Benefits, Promotions / Appraisal                                   110
# Job Security, Promotions / Appraisal                                         77
# Job Security                                                                 67
#                                                                            ...
# Company Culture, Work Life Balance, Salary & Benefits                         1
# Company Culture, Work Satisfaction, Skill Development / Learning              1
# Skill Development / Learning, Work Satisfaction, Promotions / Appraisal       1
# Skill Development / Learning, Promotions / Appraisal, Job Security            1
# Skill Development / Learning, Job Security, Promotions / Appraisal            1
# Name: count, Length: 124, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar chart 
df['rating'].head(10).value_counts().plot(kind='bar')
plt.show()

# %%
# Bar chart 
df['reviewers'].head(10).value_counts().plot(kind='bar')
plt.show()

# %%
# Bar chart 
df['highly_ratedFOR'].head(10).value_counts().plot(kind='bar')
plt.show()

# %%
# Bar chart 
df['critically_ratedFOR'].head(10).value_counts().plot(kind='bar')
plt.show()
